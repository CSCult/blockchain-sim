# %% [markdown]
# # CSCult
# # Project BlockChain Simulator
#
# ## Purna Jain (EN19CS303036)

# %%
import hashlib                 # hashlib for hashing algorithms
from datetime import datetime        # datetime is for dates
import random

# %%
class Box():
    def __init__(self,index, height, timestamp, previous_hash, txt):
        self.index = index
        self.height = height
        self.timestamp = timestamp
        self.previous_hash = prev_hash
        self.txs = txs
        self.hash = hash

# %%
Block_Chain= []

# %%
def hashing(self, p):
    self.p =p
    self.hashValue = hashlib.sha256(value.encode('utf-8')).hexdigest()

# %%
def hash(self, string):
    string = string.encode()
    sha = hashlib.sha256(string).hexdigest()
    return sha

# %%
 def merkle_root_hash(self, txt):
        if (len(txt) == 1):
            return txt[0]
        # New list to store merkle root hash
        newtxt = []
        for i in range(0, len(txs)-1, 2):
            newtxt.append(self.hashing(str(txt[i]) + str(txt[i+1])))
        if len(txt)%2 == 1:
            newtxt.append(self.hashing(str(txt[-1]) + str(txt[-1])))
        return self.merkle_root_hash(newtxt)

# %%
def create_genesis_block():
    return Block(0, datetime.now(), "Genesis Block", "0",'txs')

# %%
Block_Chain.append(create_genesis_block())

# %%
def next_block(last_block):
    this_index = last_block.index + 1
    this_timestamp = datetime.now()
    this_previous_hash = previous_hash
    
    this_hash = last_block.hash
    
    return Block(this_index, this_timestamp,this_previous_hash ,this_hash)

# %%
for i in range(0,20):
    Block_Chain.append(next_block(Block_Chain[-1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-90987dd5b43d> in <module>
#       1 for i in range(0,20):
# ----> 2     Block_Chain.append(next_block(Block_Chain[-1]))
#
# <ipython-input-70-7165ccacb157> in next_block(last_block)
#       2     this_index = last_block.index + 1
#       3     this_timestamp = datetime.now()
# ----> 4     this_previous_hash = previous_hash
#       5
#       6     this_hash = last_block.hash
#
# NameError: name 'previous_hash' is not defined

# %%
for block in Block_Chain:
    print(block)
