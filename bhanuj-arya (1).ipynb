# %% [markdown]
# # BlockChain Simulator
#
# ## Bhanuj Arya (EN19CS303020)

# %%
import hashlib                 # hashlib for hashing algorithms
from datetime import datetime        # datetime for dates
import random

# %%
class Block():
    def __init__(self,index, height, prev_hash, transactions,timestamp ):
        self.index = index
        self.height = height
        self.prev_hash = prev_hash
        self.transactions = transactions
        self.timestamp = timestamp
       
        self.hash = hash

# %%
BlockChain = []

# %%
def hashing(self, s):
    self.s =s
    self.hashValue = hashlib.sha256(value.encode('utf-8')).hexdigest()

# %%
def hash(self, string):
    string = string.encode()
    sha = hashlib.sha256(string).hexdigest()
    return sha

# %%
 def merkle_root_hash(self, transactions):
        if (len(transactions) == 1):
            return transactions[0]
        # New list for storing merkle root hashes
        newtransactions = []
        for i in range(0, len(transactions)-1, 2):
            newtransactions.append(self.hashing(str(transactions[i]) + str(transactions[i+1])))
        if len(transactions)%2 == 1:
            newtransactions.append(self.hashing(str(transactions[-1]) + str(transactions[-1])))
        return self.merkle_root_hash(newtransactions)

# %%
def create_genesis_block():
    return Block(0, datetime.now(), "Genesis Block", "0",'transactions')

# %%
BlockChain.append(create_genesis_block())

# %%
def next_block(last_block):
    this_index = last_block.index + 1
    this_timestamp = datetime.now()
   
    this_hash = last_block.hash
    
    return Block(this_index, this_timestamp,this_hash,)

# %%
for i in range(0,20):
    BlockChain.append(next_block(BlockChain[-1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-21e546b85880> in <module>
#       1 for i in range(0,20):
# ----> 2     BlockChain.append(next_block(BlockChain[-1]))
#
# <ipython-input-12-ed049c99f0dc> in next_block(last_block)
#       5     this_hash = last_block.hash
#       6
# ----> 7     return Block(this_index, this_timestamp,this_hash,)
#
# TypeError: __init__() missing 2 required positional arguments: 'transactions' and 'timestamp'

# %%
for i in BlockChain:
    print(i)
# Out:
# <__main__.Block object at 0x7fcdd1e80050>
